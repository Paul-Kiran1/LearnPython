# %%
# Dictionary

# %%
fruit={"Mango":50,"Apple":30,"Guava":40,"Strawberry":60}

# %%
fruit
# Out:
# {'Mango': 50, 'Apple': 30, 'Guava': 40, 'Strawberry': 60}

# %%
type(fruit)
# Out:
# dict

# %%
fruit.keys()
# Out:
# dict_keys(['Mango', 'Apple', 'Guava', 'Strawberry'])

# %%
fruit.values()
# Out:
# dict_values([50, 30, 40, 60])

# %%
fruit["Grapes"]=80

# %%
fruit
# Out:
# {'Mango': 50, 'Apple': 30, 'Guava': 40, 'Strawberry': 60, 'Grapes': 80}

# %%
fruit["Apple"]=250

# %%
fruit
# Out:
# {'Mango': 50, 'Apple': 250, 'Guava': 40, 'Strawberry': 60, 'Grapes': 80}

# %%
fruit1={"Apple":10,"Banana":20}
fruit2={"Coconut":30,"Litchi":40}

fruit1.update(fruit2)

# %%
fruit1
# Out:
# {'Apple': 10, 'Banana': 20, 'Coconut': 30, 'Litchi': 40}

# %%
fruit1,fruit2
# Out:
# ({'Apple': 10, 'Banana': 20, 'Coconut': 30, 'Litchi': 40},
#  {'Coconut': 30, 'Litchi': 40})

# %%
fruit
# Out:
# {'Mango': 50, 'Apple': 250, 'Guava': 40, 'Strawberry': 60, 'Grapes': 80}

# %%
fruit={"Apple":10,"Orange":20,"Guava":30,"Straawberry":40}
fruit
# Out:
# {'Apple': 10, 'Orange': 20, 'Guava': 30, 'Straawberry': 40}

# %%
fruit.pop("Guava")
fruit
# Out:
# {'Apple': 10, 'Orange': 20, 'Straawberry': 40}

# %%
fruit
# Out:
# {'Apple': 10, 'Orange': 20, 'Straawberry': 40}

# %%
fruit["Pinapple"]=50

# %%
fruit
# Out:
# {'Apple': 10, 'Orange': 20, 'Straawberry': 40, 'Pinapple': 50}

# %%
fruit.pop("Orange")
# Out:
# 20

# %%
fruit
# Out:
# {'Apple': 10, 'Straawberry': 40, 'Pinapple': 50}

# %%
len(fruit)
# Out:
# 3

# %%
max(fruit)
# Out:
# 'Straawberry'

# %%
min(fruit)
# Out:
# 'Apple'
