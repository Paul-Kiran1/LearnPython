# %% [markdown]
# *List Data Structure*

# %%
list=[]
print(list)
# Out:
# []

# %%
type(list)
# Out:
# list

# %%
l=[10,20,30,"A","B",10.4,True,10+6j]

# %%
type(l)
# Out:
# list

# %%
list1=input("Enter input: ")
lint=eval(list1)
print(lint)
# Out:
# Enter input:  10,20,"Paul",10.6,True,10+6j
# (10, 20, 'Paul', 10.6, True, (10+6j))

# %%
type(lint)
# Out:
# tuple

# %%
user_input_string = input("Enter a list (e.g., [1, 'hello', 3.14]): ")
my_list = eval(user_input_string)

print("The entered list is:", my_list)
print("Type of my_list:", type(my_list))
# Out:
# Enter a list (e.g., [1, 'hello', 3.14]):  10,20,"Paul",10.6,True
# The entered list is: (10, 20, 'Paul', 10.6, True)
# Type of my_list: <class 'tuple'>

# %%
li = input("Enter elements separated by space: ").split()
print("List:", li)
# Out:
# Enter elements separated by space:  10,20,"Paul",10.6,True
# List: ['10,20,"Paul",10.6,True']

# %%
type(li)
# Out:
# list

# %%
lit1=list(range(1,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 lit1=list(range(1,10))
#
# TypeError: 'list' object is not callable

# %%
list5=[10,20,30,[4,50]]

# %%
type(list5)
# Out:
# list

# %%
list16=[10,20,30,40]

# %%
print(list16[0])
# Out:
# 10

# %%
print(list16[-1])
# Out:
# 40

# %%
list17=[1,2,4,6,8,9,3,]

# %%
print(list17[0:6:2])
# Out:
# [1, 4, 8]

# %%
print(list17[0:9:3])
# Out:
# [1, 6, 3]

# %%
print(list17[0:0:1])
# Out:
# []

# %%
list18=[10,20,50,60,80]

# %%
print(list18)
# Out:
# [10, 20, 50, 60, 80]

# %%
list18[1]=888

# %%
print(list18)
# Out:
# [10, 888, 50, 60, 80]

# %% [markdown]
# Traversing list for

# %%
list20=[10,20,30,50,60]

# %%
for i in list20:
    print(i)
# Out:
# 10
# 20
# 30
# 50
# 60

# %%
list21=[0,12,24,36,4,5,6,7,8,9]

# %%
i=0
while i<len(list21):
    print(list21[i])
    i=i+1
# Out:
# 0
# 12
# 24
# 36
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# write a prgram to find our only even vlue from list

# %%
n=[21,42,56,47,38,57,89,43]
for i in n:
   if i%2==0:
       print(i)
   # else:
       # print("even values are not there")
# Out:
# 42
# 56
# 38

# %%
for i in n:
    if i%2!=0:
        print(i)
# Out:
# 21
# 47
# 57
# 89
# 43
