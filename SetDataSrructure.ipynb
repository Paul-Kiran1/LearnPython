# %%
# Set

# %%
s={"a","b","c","d","e","f","a","a","b","c"}
s
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f'}

# %%
s.add("sparta")

# %%
s
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f', 'sparta'}

# %%
s.remove("d")

# %%
s
# Out:
# {'a', 'b', 'c', 'e', 'f', 'sparta'}

# %%
s.update([10,True,30,1+6j])

# %%
s
# Out:
# {(1+6j), 10, 30, True, 'a', 'b', 'c', 'e', 'f', 'sparta'}

# %%
s.remove(True)

# %%
s
# Out:
# {(1+6j), 10, 30, 'a', 'b', 'c', 'e', 'f', 'sparta'}

# %%
type(s)
# Out:
# set

# %%
s1={1,"dc",2,3,"Te"}
s2={4,"a",5,"b",6,7}
s2.union(s1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'Te', 'a', 'b', 'dc'}

# %%
s1
# Out:
# {1, 2, 3, 'Te', 'dc'}

# %%
s2
# Out:
# {4, 5, 6, 7, 'a', 'b'}

# %%
s2.intersection(s1)
# Out:
# set()

# %%
s3={1,2,3,4,5,6,7}
s4={1,3,5,7,9,11,13}
s3.intersection(s4)
# Out:
# {1, 3, 5, 7}
